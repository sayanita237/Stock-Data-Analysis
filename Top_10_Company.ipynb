# %%
import yfinance as yf
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
import datetime

# %%
df1 = pd.read_csv('ADANIENT.csv')
df2 = pd.read_csv('ADANIPORTS.csv')
df3 =pd.read_csv('APOLLOHOSP.csv')
df4 =pd.read_csv('ASIANPAINT.csv')
df5 =pd.read_csv('AXISBANK.csv')
df6 =pd.read_csv('BAJAJ-AUTO.csv')
df7 =pd.read_csv('BAJAJFINSV.csv')
df8 =pd.read_csv('BAJFINANCE.csv')
df9 =pd.read_csv('BHARTIARTL.csv')
df10 =pd.read_csv('BPCL.csv')
df11 =pd.read_csv('BRITANNIA.csv')
df12 =pd.read_csv('CIPLA.csv')
df13 =pd.read_csv('COALINDIA.csv')
df14 =pd.read_csv('WIPRO.csv')
df15 =pd.read_csv('DIVISLAB.csv')
df16 =pd.read_csv('DRREDDY.csv')
df17 =pd.read_csv('EICHERMOT.csv')
df18 =pd.read_csv('GRASIM.csv')
df19 =pd.read_csv('HCLTECH.csv')
df20 =pd.read_csv('HDFC.csv')
df21 =pd.read_csv('HDFCBANK.csv')
df22 =pd.read_csv('HDFCLIFE.csv')
df23 =pd.read_csv('HEROMOTOCO.csv')
df24 =pd.read_csv('HINDALCO.csv')
df25 =pd.read_csv('HINDUNILVR.csv')
df26 =pd.read_csv('ICICIBANK.csv')
df27 =pd.read_csv('UPL.csv')
df28 =pd.read_csv('INDUSINDBK.csv')
df29 =pd.read_csv('INFY.csv')
df30 =pd.read_csv('ITC.csv')
df31 =pd.read_csv('JSWSTEEL.csv')
df32 =pd.read_csv('KOTAKBANK.csv')
df33 =pd.read_csv('LT.csv')
df34 =pd.read_csv('M&M.csv')
df35 =pd.read_csv('MARUTI.csv')
df36 =pd.read_csv('NESTLEIND.csv')
df37 =pd.read_csv('NIFTY_50.csv')
df38 =pd.read_csv('NTPC.csv')
df39 =pd.read_csv('ONGC.csv')
df40 =pd.read_csv('POWERGRID.csv')
df41 =pd.read_csv('RELIANCE.csv')
df42 =pd.read_csv('SBILIFE.csv')
df43 =pd.read_csv('SBIN.csv')
df44 =pd.read_csv('SUNPHARMA.csv')
df45 =pd.read_csv('TATACONSUM.csv')
df46 =pd.read_csv('TATAMOTORS.csv')
df47 =pd.read_csv('TATASTEEL.csv')
df48 =pd.read_csv('TCS.csv')
df49 =pd.read_csv('TECHM.csv')
df50 =pd.read_csv('TITAN.csv')
df51 =pd.read_csv('ULTRACEMCO.csv')

# %%
df1['ADANIENT']=df1['c']
df2['ADANIPORTS']=df2['c']
df3['APOLLOHOSP']=df3['c']
df4['ASIANPAINT']=df4['c']
df5['AXISBANK']=df5['c']
df6['BAJAJ-AUTO']=df6['c']
df7['BAJAJFINSV']=df7['c']
df8['BAJFINANCE']=df8['c']
df9['BHARTIARTL']=df9['c']
df10['BPCL']=df10['c']
df11['BRITANNIA']=df11['c']
df12['CIPLA']=df12['c']
df13['COALINDIA']=df13['c']
df14['WIPRO']=df14['c']
df15['DIVISLAB']=df15['c']
df16['DRREDDY']=df16['c']
df17['EICHERMOT']=df17['c']
df18['GRASIM']=df18['c']
df19['HCLTECH']=df19['c']
df20['HDFC']=df20['c']
df21['HDFCBANK']=df21['c']
df22['HDFCLIFE']=df22['c']
df23['HEROMOTOCO']=df23['c']
df24['HINDALCO']=df24['c']
df25['HINDUNILVR']=df25['c']
df26['ICICIBANK']=df26['c']
df27['UPL']=df27['c']
df28['INDUSINDBK']=df28['c']
df29['INFY']=df29['c']
df30['ITC']=df30['c']
df31['JSWSTEEL']=df31['c']
df32['KOTAKBANK']=df32['c']
df33['LT']=df33['c']
df34['M&M']=df34['c']
df35['MARUTI']=df35['c']
df36['NESTLEIND']=df36['c']
df37['NIFTY_50']=df37['c']
df38['NTPC']=df38['c']
df39['ONGC']=df39['c']
df40['POWERGRID']=df40['c']
df41['RELIANCE']=df41['c']
df42['SBILIFE']=df42['c']
df43['SBIN']=df43['c']
df44['SUNPHARMA']=df44['c']
df45['TATACONSUM']=df45['c']
df46['TATAMOTORS']=df46['c']
df47['TATASTEEL']=df47['c']
df48['TCS']=df48['c']
df49['TECHM']=df49['c']
df50['TITAN']=df50['c']
df51['ULTRACEMCO']=df51['c']

# %%
df = pd.DataFrame([df1['ADANIENT'],
df2['ADANIPORTS'],
df3['APOLLOHOSP'],
df4['ASIANPAINT'],
df5['AXISBANK'],
df6['BAJAJ-AUTO'],
df7['BAJAJFINSV'],
df8['BAJFINANCE'],
df9['BHARTIARTL'],
df10['BPCL'],
df11['BRITANNIA'],
df12['CIPLA'],
df13['COALINDIA'],
df14['WIPRO'],
df15['DIVISLAB'],
df16['DRREDDY'],
df17['EICHERMOT'],
df18['GRASIM'],
df19['HCLTECH'],
df20['HDFC'],
df21['HDFCBANK'],
df22['HDFCLIFE'],
df23['HEROMOTOCO'],
df24['HINDALCO'],
df25['HINDUNILVR'],
df26['ICICIBANK'],
df27['UPL'],
df28['INDUSINDBK'],
df29['INFY'],
df30['ITC'],
df31['JSWSTEEL'],
df32['KOTAKBANK'],
df33['LT'],
df34['M&M'],
df35['MARUTI'],
df36['NESTLEIND'],
df37['NIFTY_50'],
df38['NTPC'],
df39['ONGC'],
df40['POWERGRID'],
df41['RELIANCE'],
df42['SBILIFE'],
df43['SBIN'],
df44['SUNPHARMA'],
df45['TATACONSUM'],
df46['TATAMOTORS'],
df47['TATASTEEL'],
df48['TCS'],
df49['TECHM'],
df50['TITAN'],
df51['ULTRACEMCO']
])
df.T
# Out:
#       ADANIENT  ADANIPORTS  APOLLOHOSP  ASIANPAINT  AXISBANK  BAJAJ-AUTO  \
# 0       224.45      150.35      833.00      464.71    288.23     1762.85
# 1       215.95      147.30      834.35      464.95    288.96     1805.00
# 2       215.95      145.50      833.35      465.21    300.68     1838.00
# 3       212.85      144.85      825.65      470.55    297.27     1895.70
# 4       216.95      145.40      824.90      471.38    295.08     1900.00
# ...        ...         ...         ...         ...       ...         ...
# 2468   1847.25      657.75     4320.20     2786.75    851.05     4286.00
# 2469   1870.75      661.65     4398.30     2809.75    864.35     4288.35
# 2470   1878.75      664.70     4386.70     2843.10    864.55     4254.35
# 2471   1850.95      658.55     4338.65     2854.60    863.35     4209.25
# 2472   1853.85      658.40     4320.30     2809.70    873.40     4265.80
#
#       BAJAJFINSV  BAJFINANCE  BHARTIARTL    BPCL  ...  SBILIFE    SBIN  \
# ...

# %%
df_close = df.T
df_close
# Out:
#       ADANIENT  ADANIPORTS  APOLLOHOSP  ASIANPAINT  AXISBANK  BAJAJ-AUTO  \
# 0       224.45      150.35      833.00      464.71    288.23     1762.85
# 1       215.95      147.30      834.35      464.95    288.96     1805.00
# 2       215.95      145.50      833.35      465.21    300.68     1838.00
# 3       212.85      144.85      825.65      470.55    297.27     1895.70
# 4       216.95      145.40      824.90      471.38    295.08     1900.00
# ...        ...         ...         ...         ...       ...         ...
# 2468   1847.25      657.75     4320.20     2786.75    851.05     4286.00
# 2469   1870.75      661.65     4398.30     2809.75    864.35     4288.35
# 2470   1878.75      664.70     4386.70     2843.10    864.55     4254.35
# 2471   1850.95      658.55     4338.65     2854.60    863.35     4209.25
# 2472   1853.85      658.40     4320.30     2809.70    873.40     4265.80
#
#       BAJAJFINSV  BAJFINANCE  BHARTIARTL    BPCL  ...  SBILIFE    SBIN  \
# ...

# %%
df1['Date']=df1['time']

# %%
df_new = df_close.join(df1['Date'])

# %%
df_new = df_new.set_index(pd.DatetimeIndex(df_new['Date'].values))

# %%
# Make DataFrame with Date index

# %%
df_new.drop(['Date'], axis=1, inplace=True)

# %%
df_new
# Out:
#             ADANIENT  ADANIPORTS  APOLLOHOSP  ASIANPAINT  AXISBANK  \
# 2013-04-22    224.45      150.35      833.00      464.71    288.23
# 2013-04-23    215.95      147.30      834.35      464.95    288.96
# 2013-04-25    215.95      145.50      833.35      465.21    300.68
# 2013-04-26    212.85      144.85      825.65      470.55    297.27
# 2013-04-29    216.95      145.40      824.90      471.38    295.08
# ...              ...         ...         ...         ...       ...
# 2023-04-12   1847.25      657.75     4320.20     2786.75    851.05
# 2023-04-13   1870.75      661.65     4398.30     2809.75    864.35
# 2023-04-17   1878.75      664.70     4386.70     2843.10    864.55
# 2023-04-18   1850.95      658.55     4338.65     2854.60    863.35
# 2023-04-19   1853.85      658.40     4320.30     2809.70    873.40
#
#             BAJAJ-AUTO  BAJAJFINSV  BAJFINANCE  BHARTIARTL    BPCL  ...  \
# 2013-04-22     1762.85       77.65      122.21      294.85  138.23  ...
# ...

# %%
# Calculate Daily Return

# %%
daily_return = df_new.pct_change()
daily_return
# Out:
#             ADANIENT  ADANIPORTS  APOLLOHOSP  ASIANPAINT  AXISBANK  \
# 2013-04-22       NaN         NaN         NaN         NaN       NaN
# 2013-04-23 -0.037870   -0.020286    0.001621    0.000516  0.002533
# 2013-04-25  0.000000   -0.012220   -0.001199    0.000559  0.040559
# 2013-04-26 -0.014355   -0.004467   -0.009240    0.011479 -0.011341
# 2013-04-29  0.019262    0.003797   -0.000908    0.001764 -0.007367
# ...              ...         ...         ...         ...       ...
# 2023-04-12  0.024457    0.005811    0.011449    0.011965 -0.002637
# 2023-04-13  0.012722    0.005929    0.018078    0.008253  0.015628
# 2023-04-17  0.004276    0.004610   -0.002637    0.011869  0.000231
# 2023-04-18 -0.014797   -0.009252   -0.010954    0.004045 -0.001388
# 2023-04-19  0.001567   -0.000228   -0.004229   -0.015729  0.011641
#
#             BAJAJ-AUTO  BAJAJFINSV  BAJFINANCE  BHARTIARTL      BPCL  ...  \
# 2013-04-22         NaN         NaN         NaN         NaN       NaN  ...
# ...

# %%
# Calculate Annual Return

# %%
annual_return = daily_return.mean() * 252
sorted_c = annual_return.sort_values(ascending=False).head(10)

# %%
sorted_c
# Out:
# BAJFINANCE    0.468806
# ADANIENT      0.451776
# BAJAJFINSV    0.348652
# BRITANNIA     0.312790
# EICHERMOT     0.303329
# JSWSTEEL      0.299260
# UPL           0.285283
# TITAN         0.281822
# HINDALCO      0.239590
# DIVISLAB      0.238715
# dtype: float64

# %%
plt.figure(figsize=(20,6))
plt.bar(sorted_c.index, sorted_c)
plt.xticks(rotation=90);
